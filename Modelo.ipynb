# %%
import numpy as np
import pandas as pd
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split

# %%
#Carregando as bases para treinar o modelo
train = pd.read_csv('train.csv')
test = pd.read_csv('test.csv')

# %%
 #Modelo
model = RandomForestClassifier(n_estimators = 100, n_jobs = -1, random_state = 0)

# %%
#Função que transforma sexo M e F para 1 e 0, respectivamente
def sex_transform(value):
    if value == "female":
        return 1
    else:
        return 0

# %%
#Aplicando a função em cada elemento da base
train['Sex_Binary'] = train['Sex'].map(sex_transform)

# %%
#Variáveis que o modelo utilizara
variables = ['Sex_Binary', 'Age']

# %%
#Definindo eixo x e y do modelo
X = train[variables]
X = X.fillna(-1) #Removendo o "NaN" da tabela
y = train['Survived']

# %%
# "Ensinando" o modelo
model.fit(X, y)
# Out:
# RandomForestClassifier(n_jobs=-1, random_state=0)

# %%
test['Sex_Binary'] = test['Sex'].map(sex_transform)
X_prev = test[variables]
X_prev = X_prev.fillna(-1)

# %%
p = model.predict(X_prev)

# %%
sub = pd.Series(p, index=test['PassengerId'], name = 'Survived')

# %%
sub.to_csv("primeiro_modelo.csv", header = True )
